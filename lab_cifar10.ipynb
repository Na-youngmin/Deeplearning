# %% [markdown]
# 학번: 20183217
#
# 이름: 나영민

# %% [markdown]
# # 1. Convolutional Neural Networks
# ---
# 이번 실습에서는 **CNN**을 활용하여 CIFAR-10 dataset에 적용을 해보도록 하겠습니다.
#
# CIFAR-10 dataset은 작은 크기의 color image들을 10개 class로 분류되어 있는 dataset입니다.
# 아래 그림이 dataset에 대한 예제입니다.
#
# 각 이미지는 3x32x32 크기의 image입니다.

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# 이번 실습에서 GPU를 통해서 연산하고 Neural network 학습을 진행하겠습니다.
# 아래 셀을 통해서 GPU 실행 가능 여부를 확인합니다.

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()
#train_on_gpu = False

if not train_on_gpu:
    device = 'cpu'
    print('CUDA is not available.  Training on CPU ...')
else:
    device = 'cuda'
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Data는 torchvision을 통해서 제공 되기 때문에 이를 통해서 받도록 하겠습니다.
#
# 이번 실습에서는 validation set을 분류하는 작업을 수행도 하도록 하겠습니다.
#
# - `SubsetRandomSampler` class를 통해서 전체 dataset의 일정 부분을 나눠서 사용할 수 있습니다.
# - 예를 들어서 10000개의 data가 있다고 가정했을때, 0:6999 의 샘플은 training set으로, 7000:9999는 validation set으로 나눈다고 하면
#     - `train_sampler = SubsetRandomSampler(train_idx)`
#     - `valid_sampler = SubsetRandomSampler(valid_idx)`
#     - `train_idx`는 0:6999 를 갖는 인덱스 tensor로 정의하고
#     - `valid_idx`는 7000:9999 를 갖는 인덱스 tensor로 정의합니다.
# - `train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
#     sampler=train_sampler, num_workers=num_workers)`
# - `valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
#     sampler=valid_sampler, num_workers=num_workers)`
# - 위와 같이 dataloader를 사용하면, `sampler`파라메터에 정의 되어 있는 인덱스만 이용해서 dataloader를 생성합니다.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# how many samples per batch to load
batch_size = 64

# %% [markdown]
# ## Download CIFAR10 dataset from torchvision

# %%
# convert data to a normalized torch.FloatTensor

train_transform = transforms.Compose([
    transforms.RandomRotation(25),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=train_transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_data
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-25.0, 25.0], interpolation=nearest, expand=False, fill=0)
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
test_data
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %% [markdown]
# ## Spliting training and validation set

# %%
# obtain training indices that will be used for validation
# percentage of training set to use as validation
valid_size = 0.2

num_train = len(train_data)
num_train = int(num_train/5)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]


# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Kfold validation with sklearn
#
# - K-fold validation의 경우는 `sklearn` package의 `StratifiedKFold`, 또는 `KFold`를 사용하면 편하게 관리가 가능합니다
# - 아래 코드 template만 제공합니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True)

# %% [markdown]
# 아래 코드는 template 입니다.

# %%
# def reset_weights(m):
#   '''
#     Try resetting model weights to avoid
#     weight leakage.
#   '''
#   for layer in m.children():
#    if hasattr(layer, 'reset_parameters'):
#     print(f'Reset trainable parameters of layer = {layer}')
#     layer.reset_parameters()


# epoch = 2

# for fold, (train_ind, valid_ind) in enumerate(kf.split(train_data)):
#     print('Starting fold = ', fold)
    
#     train_sampler_kfold = SubsetRandomSampler(train_ind)
#     valid_sampler_kfold = SubsetRandomSampler(valid_ind)
#     train_loader_kfold = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
#     sampler=train_sampler_kfold, num_workers=num_workers)
#     valid_loader_kfold = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
#     sampler=valid_sampler_kfold, num_workers=num_workers)
    
#     model = MyConvNet()
#     model.apply(reset_weights)

#     for e in np.arange(epoch): 
#         print('Starting epoch = ', e)
        
#         # Training
#         for Xtrain, ytrain in train_loader_kfold:
            
#         # Validation
#         with torch.no_grad():
#             for Xtrain, ytrain in valid_loader_kfold:

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, int(20/2), idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Convolution Network
#
#
# <img src="https://drive.google.com/uc?export=download&id=135IBuqU3OHX70cenYP9ssfJby5FHj8Ky" height=50% width=50%  />
#
# ## Problem 1: 다음 구조를 갖는 convolution network을 만드세요
#
# - 3개의 convolution layer
#   - `conv1`:
#     - filter 수 16개
#     - filter 크기: 3x3
#     - padding = 1
#     - stride = 1
#
#   - `conv2`:
#     - filter 수 32개
#     - filter 크기: 3x3
#     - padding = 1
#     - stride = 1
#
#   - `conv3`:
#     - filter 수 64개
#     - filter 크기: 3x3
#     - padding = 1
#     - stride = 1
#
# - Maxpool layer
#     - filter 크기 2x2
#     - stride 2
#     - `conv1`, `conv2`, `conv3` 이후에 각각 적용
#
# - 2개의 FCN layer
#     - `dropout` 적용 p=0.25 (최종 layer에 적용하나요?)
#     - `fc1`
#         - output neuron의 수: 500
#     - `fc2`
#         - 네트워크의 최종 output layer이며 Linear layer로 구성 (즉, softmax는 loss 함수에서 적용할 것)
#
#
# 아래 비어있는 부분을 완성하세요.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # convolutional layer (sees 3x32x32 image tensor)
        self.conv1 = nn.Conv2d(3,16,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # convolutional layer (sees 16x16x16 tensor)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # convolutional layer (sees 32x8x8 tensor)
        self.conv3 = nn.Conv2d(32,64, kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding = 0)
        # linear layer (64 * 4 * 4 -> 500)
        self.fc1 = nn.Linear(1024,500)
        # linear layer (500 -> 10)
        self.fc2 = nn.Linear(500,10)
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)
        self.relu = nn.ReLU(True)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        # flatten image input
        x = x.reshape(-1, 64 * 4 * 4)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = self.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = self.fc2(x)
        return x

# create a complete CNN
model = ConvNet()

# move tensors to GPU if CUDA is available
model.to(device)
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (relu): ReLU(inplace=True)
# )

# %% [markdown]
# ## Problem 2
#
# 본 classification 문제를 위해서 적절한 cost함수와 optimizer를 선언하세요

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# ---
# ## Problem 3: Train and validation
#
# - Training을 하고 각 epoch별로 validation을 수행하세요
#     - 아래 epoch 별로 training loss, training accuracy, validation loss, validation accuracy를 저장하세요
#     - `loss`가 최소인 model의 `state_dict`를 `model_cifar.pt`라는 파일명으로 저장하세요

# %%
# number of epochs to train the model
n_epochs = 80

valid_loss_min = np.Inf # track change in validation loss

# keep track of training and validation loss
train_loss = torch.zeros(n_epochs)
valid_loss = torch.zeros(n_epochs)

train_acc = torch.zeros(n_epochs)
valid_acc = torch.zeros(n_epochs)

for e in range(0, n_epochs):
    if e % 15 == 0:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.5

   
    ###################
    # train the model #
    ###################
    model.train()
    for data, labels in train_loader:
        # move tensors to GPU if CUDA is available
        data, labels = data.to(device), labels.to(device)
        # clear the gradients of all optimized variables
        
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        logits = model(data)
        # calculate the batch loss
        loss = criterion(logits, labels)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss[e] += loss.item()
        
        ps = F.softmax(logits, dim=1)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.reshape(top_class.shape)
        train_acc[e] += torch.mean(equals.type(torch.float)).detach().cpu()
    
    train_loss[e] /= len(train_loader)
    train_acc[e] /= len(train_loader)
        
        
    ######################    
    # validate the model #
    ######################
    with torch.no_grad(): 
        model.eval()
        for data, labels in valid_loader:
            # move tensors to GPU if CUDA is available
            data, labels = data.to(device), labels.to(device)
            # forward pass: compute predicted outputs by passing inputs to the model
            logits = model(data)
            # calculate the batch loss
            loss = criterion(logits, labels)
            # update average validation loss 
            valid_loss[e] += loss.item()

            ps = F.softmax(logits, dim=1)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.reshape(top_class.shape)
            valid_acc[e] += torch.mean(equals.type(torch.float)).detach().cpu()
    
    # calculate average losses
    valid_loss[e] /= len(valid_loader)
    valid_acc[e] /= len(valid_loader)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        e, train_loss[e], valid_loss[e]))
    
    # print training/validation statistics 
    print('Epoch: {} \tTraining accuracy: {:.6f} \tValidation accuracy: {:.6f}'.format(
        e, train_acc[e], valid_acc[e]))
    
    # save model if validation loss has decreased
    if valid_loss[e] <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss[e]))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss[e]
# Out:
# Epoch: 0 	Training Loss: 2.297814 	Validation Loss: 2.281246
# Epoch: 0 	Training accuracy: 0.129625 	Validation accuracy: 0.198242
# Validation loss decreased (inf --> 2.281246).  Saving model ...
# Epoch: 1 	Training Loss: 2.188536 	Validation Loss: 2.055864
# Epoch: 1 	Training accuracy: 0.201375 	Validation accuracy: 0.267090
# Validation loss decreased (2.281246 --> 2.055864).  Saving model ...
# Epoch: 2 	Training Loss: 1.997126 	Validation Loss: 1.912268
# Epoch: 2 	Training accuracy: 0.270625 	Validation accuracy: 0.321777
# Validation loss decreased (2.055864 --> 1.912268).  Saving model ...
# Epoch: 3 	Training Loss: 1.889614 	Validation Loss: 1.819166
# Epoch: 3 	Training accuracy: 0.310250 	Validation accuracy: 0.353516
# Validation loss decreased (1.912268 --> 1.819166).  Saving model ...
# Epoch: 4 	Training Loss: 1.805502 	Validation Loss: 1.742040
# Epoch: 4 	Training accuracy: 0.342000 	Validation accuracy: 0.368164
# Validation loss decreased (1.819166 --> 1.742040).  Saving model ...
# Epoch: 5 	Training Loss: 1.740336 	Validation Loss: 1.668428
# Epoch: 5 	Training accuracy: 0.365125 	Validation accuracy: 0.397949
# Validation loss decreased (1.742040 --> 1.668428).  Saving model ...
# Epoch: 6 	Training Loss: 1.676851 	Validation Loss: 1.655497
# Epoch: 6 	Training accuracy: 0.389875 	Validation accuracy: 0.394043
# Validation loss decreased (1.668428 --> 1.655497).  Saving model ...
# Epoch: 7 	Training Loss: 1.642627 	Validation Loss: 1.603413
# Epoch: 7 	Training accuracy: 0.398000 	Validation accuracy: 0.402344
# Validation loss decreased (1.655497 --> 1.603413).  Saving model ...
# Epoch: 8 	Training Loss: 1.604827 	Validation Loss: 1.535788
# Epoch: 8 	Training accuracy: 0.419750 	Validation accuracy: 0.453613
# Validation loss decreased (1.603413 --> 1.535788).  Saving model ...
# Epoch: 9 	Training Loss: 1.556333 	Validation Loss: 1.468108
# Epoch: 9 	Training accuracy: 0.435625 	Validation accuracy: 0.461426
# Validation loss decreased (1.535788 --> 1.468108).  Saving model ...
# Epoch: 10 	Training Loss: 1.523504 	Validation Loss: 1.469220
# Epoch: 10 	Training accuracy: 0.444750 	Validation accuracy: 0.466309
# Epoch: 11 	Training Loss: 1.499864 	Validation Loss: 1.452871
# Epoch: 11 	Training accuracy: 0.456625 	Validation accuracy: 0.491211
# Validation loss decreased (1.468108 --> 1.452871).  Saving model ...
# Epoch: 12 	Training Loss: 1.461032 	Validation Loss: 1.528211
# Epoch: 12 	Training accuracy: 0.474875 	Validation accuracy: 0.466797
# Epoch: 13 	Training Loss: 1.446103 	Validation Loss: 1.388936
# Epoch: 13 	Training accuracy: 0.477625 	Validation accuracy: 0.496094
# Validation loss decreased (1.452871 --> 1.388936).  Saving model ...
# Epoch: 14 	Training Loss: 1.416772 	Validation Loss: 1.415545
# Epoch: 14 	Training accuracy: 0.483500 	Validation accuracy: 0.487305
# Epoch: 15 	Training Loss: 1.349146 	Validation Loss: 1.334379
# Epoch: 15 	Training accuracy: 0.510750 	Validation accuracy: 0.528320
# Validation loss decreased (1.388936 --> 1.334379).  Saving model ...
# Epoch: 16 	Training Loss: 1.334283 	Validation Loss: 1.336285
# Epoch: 16 	Training accuracy: 0.515125 	Validation accuracy: 0.508301
# Epoch: 17 	Training Loss: 1.324392 	Validation Loss: 1.318142
# Epoch: 17 	Training accuracy: 0.513875 	Validation accuracy: 0.523926
# Validation loss decreased (1.334379 --> 1.318142).  Saving model ...
# Epoch: 18 	Training Loss: 1.305291 	Validation Loss: 1.281223
# Epoch: 18 	Training accuracy: 0.530375 	Validation accuracy: 0.538574
# Validation loss decreased (1.318142 --> 1.281223).  Saving model ...
# Epoch: 19 	Training Loss: 1.290224 	Validation Loss: 1.294492
# Epoch: 19 	Training accuracy: 0.534625 	Validation accuracy: 0.529297
# Epoch: 20 	Training Loss: 1.276976 	Validation Loss: 1.277184
# Epoch: 20 	Training accuracy: 0.541000 	Validation accuracy: 0.539551
# Validation loss decreased (1.281223 --> 1.277184).  Saving model ...
# Epoch: 21 	Training Loss: 1.268500 	Validation Loss: 1.301060
# Epoch: 21 	Training accuracy: 0.539125 	Validation accuracy: 0.520508
# Epoch: 22 	Training Loss: 1.261399 	Validation Loss: 1.270249
# Epoch: 22 	Training accuracy: 0.543250 	Validation accuracy: 0.535645
# Validation loss decreased (1.277184 --> 1.270249).  Saving model ...
# Epoch: 23 	Training Loss: 1.240931 	Validation Loss: 1.373990
# Epoch: 23 	Training accuracy: 0.547375 	Validation accuracy: 0.515625
# Epoch: 24 	Training Loss: 1.232990 	Validation Loss: 1.288226
# Epoch: 24 	Training accuracy: 0.559250 	Validation accuracy: 0.538574
# Epoch: 25 	Training Loss: 1.206388 	Validation Loss: 1.222045
# Epoch: 25 	Training accuracy: 0.563125 	Validation accuracy: 0.556152
# Validation loss decreased (1.270249 --> 1.222045).  Saving model ...
# Epoch: 26 	Training Loss: 1.210323 	Validation Loss: 1.240468
# Epoch: 26 	Training accuracy: 0.561875 	Validation accuracy: 0.547363
# Epoch: 27 	Training Loss: 1.192313 	Validation Loss: 1.241993
# Epoch: 27 	Training accuracy: 0.568250 	Validation accuracy: 0.550293
# Epoch: 28 	Training Loss: 1.174041 	Validation Loss: 1.199340
# Epoch: 28 	Training accuracy: 0.581250 	Validation accuracy: 0.573730
# Validation loss decreased (1.222045 --> 1.199340).  Saving model ...
# Epoch: 29 	Training Loss: 1.161760 	Validation Loss: 1.215114
# Epoch: 29 	Training accuracy: 0.580500 	Validation accuracy: 0.563477
# Epoch: 30 	Training Loss: 1.114415 	Validation Loss: 1.205664
# Epoch: 30 	Training accuracy: 0.596000 	Validation accuracy: 0.569336
# Epoch: 31 	Training Loss: 1.115900 	Validation Loss: 1.168372
# Epoch: 31 	Training accuracy: 0.601875 	Validation accuracy: 0.586426
# Validation loss decreased (1.199340 --> 1.168372).  Saving model ...
# Epoch: 32 	Training Loss: 1.112871 	Validation Loss: 1.184483
# Epoch: 32 	Training accuracy: 0.601125 	Validation accuracy: 0.567871
# Epoch: 33 	Training Loss: 1.101899 	Validation Loss: 1.201395
# Epoch: 33 	Training accuracy: 0.606750 	Validation accuracy: 0.575684
# Epoch: 34 	Training Loss: 1.096228 	Validation Loss: 1.175344
# Epoch: 34 	Training accuracy: 0.608875 	Validation accuracy: 0.576172
# Epoch: 35 	Training Loss: 1.094823 	Validation Loss: 1.146549
# Epoch: 35 	Training accuracy: 0.606750 	Validation accuracy: 0.597656
# Validation loss decreased (1.168372 --> 1.146549).  Saving model ...
# Epoch: 36 	Training Loss: 1.079426 	Validation Loss: 1.186103
# Epoch: 36 	Training accuracy: 0.614125 	Validation accuracy: 0.578613
# Epoch: 37 	Training Loss: 1.073636 	Validation Loss: 1.176049
# Epoch: 37 	Training accuracy: 0.610500 	Validation accuracy: 0.581055
# Epoch: 38 	Training Loss: 1.058996 	Validation Loss: 1.167920
# Epoch: 38 	Training accuracy: 0.610750 	Validation accuracy: 0.583008
# Epoch: 39 	Training Loss: 1.057089 	Validation Loss: 1.170183
# Epoch: 39 	Training accuracy: 0.622250 	Validation accuracy: 0.583984
# Epoch: 40 	Training Loss: 1.053959 	Validation Loss: 1.158372
# Epoch: 40 	Training accuracy: 0.620625 	Validation accuracy: 0.580078
# Epoch: 41 	Training Loss: 1.054471 	Validation Loss: 1.166955
# Epoch: 41 	Training accuracy: 0.619875 	Validation accuracy: 0.579590
# Epoch: 42 	Training Loss: 1.034274 	Validation Loss: 1.163036
# Epoch: 42 	Training accuracy: 0.633750 	Validation accuracy: 0.595215
# Epoch: 43 	Training Loss: 1.031291 	Validation Loss: 1.179081
# Epoch: 43 	Training accuracy: 0.626375 	Validation accuracy: 0.586914
# Epoch: 44 	Training Loss: 1.035432 	Validation Loss: 1.134356
# Epoch: 44 	Training accuracy: 0.625625 	Validation accuracy: 0.591309
# Validation loss decreased (1.146549 --> 1.134356).  Saving model ...
# Epoch: 45 	Training Loss: 1.006096 	Validation Loss: 1.115816
# Epoch: 45 	Training accuracy: 0.638125 	Validation accuracy: 0.605469
# Validation loss decreased (1.134356 --> 1.115816).  Saving model ...
# Epoch: 46 	Training Loss: 0.990336 	Validation Loss: 1.138042
# Epoch: 46 	Training accuracy: 0.647375 	Validation accuracy: 0.596680
# Epoch: 47 	Training Loss: 0.989063 	Validation Loss: 1.163714
# Epoch: 47 	Training accuracy: 0.647625 	Validation accuracy: 0.583984
# Epoch: 48 	Training Loss: 0.987533 	Validation Loss: 1.110306
# Epoch: 48 	Training accuracy: 0.648625 	Validation accuracy: 0.604980
# Validation loss decreased (1.115816 --> 1.110306).  Saving model ...
# Epoch: 49 	Training Loss: 0.992216 	Validation Loss: 1.139075
# Epoch: 49 	Training accuracy: 0.641500 	Validation accuracy: 0.597656
# Epoch: 50 	Training Loss: 0.977436 	Validation Loss: 1.139421
# Epoch: 50 	Training accuracy: 0.649875 	Validation accuracy: 0.597168
# Epoch: 51 	Training Loss: 0.983933 	Validation Loss: 1.139017
# Epoch: 51 	Training accuracy: 0.645250 	Validation accuracy: 0.593750
# Epoch: 52 	Training Loss: 0.963232 	Validation Loss: 1.137914
# Epoch: 52 	Training accuracy: 0.651750 	Validation accuracy: 0.604492
# Epoch: 53 	Training Loss: 0.970079 	Validation Loss: 1.136881
# Epoch: 53 	Training accuracy: 0.655125 	Validation accuracy: 0.593262
# Epoch: 54 	Training Loss: 0.956874 	Validation Loss: 1.137696
# Epoch: 54 	Training accuracy: 0.654500 	Validation accuracy: 0.587891
# Epoch: 55 	Training Loss: 0.953038 	Validation Loss: 1.114323
# Epoch: 55 	Training accuracy: 0.661500 	Validation accuracy: 0.610840
# Epoch: 56 	Training Loss: 0.954218 	Validation Loss: 1.135171
# Epoch: 56 	Training accuracy: 0.658125 	Validation accuracy: 0.598145
# Epoch: 57 	Training Loss: 0.965546 	Validation Loss: 1.111446
# Epoch: 57 	Training accuracy: 0.651000 	Validation accuracy: 0.609863
# Epoch: 58 	Training Loss: 0.958366 	Validation Loss: 1.126276
# Epoch: 58 	Training accuracy: 0.655625 	Validation accuracy: 0.605957
# Epoch: 59 	Training Loss: 0.953527 	Validation Loss: 1.127622
# Epoch: 59 	Training accuracy: 0.657500 	Validation accuracy: 0.598633
# Epoch: 60 	Training Loss: 0.937673 	Validation Loss: 1.082367
# Epoch: 60 	Training accuracy: 0.667375 	Validation accuracy: 0.624023
# Validation loss decreased (1.110306 --> 1.082367).  Saving model ...
# Epoch: 61 	Training Loss: 0.940880 	Validation Loss: 1.115319
# Epoch: 61 	Training accuracy: 0.669750 	Validation accuracy: 0.595703
# Epoch: 62 	Training Loss: 0.927376 	Validation Loss: 1.103239
# Epoch: 62 	Training accuracy: 0.665125 	Validation accuracy: 0.612305
# Epoch: 63 	Training Loss: 0.925070 	Validation Loss: 1.139668
# Epoch: 63 	Training accuracy: 0.666875 	Validation accuracy: 0.597168
# Epoch: 64 	Training Loss: 0.938793 	Validation Loss: 1.121485
# Epoch: 64 	Training accuracy: 0.660000 	Validation accuracy: 0.600098
# Epoch: 65 	Training Loss: 0.926662 	Validation Loss: 1.103385
# Epoch: 65 	Training accuracy: 0.667250 	Validation accuracy: 0.624023
# Epoch: 66 	Training Loss: 0.932572 	Validation Loss: 1.107525
# Epoch: 66 	Training accuracy: 0.666625 	Validation accuracy: 0.609863
# Epoch: 67 	Training Loss: 0.924402 	Validation Loss: 1.122813
# Epoch: 67 	Training accuracy: 0.668750 	Validation accuracy: 0.613770
# Epoch: 68 	Training Loss: 0.926251 	Validation Loss: 1.105018
# Epoch: 68 	Training accuracy: 0.668375 	Validation accuracy: 0.609863
# Epoch: 69 	Training Loss: 0.921189 	Validation Loss: 1.120218
# Epoch: 69 	Training accuracy: 0.676375 	Validation accuracy: 0.610352
# Epoch: 70 	Training Loss: 0.919992 	Validation Loss: 1.096724
# Epoch: 70 	Training accuracy: 0.667875 	Validation accuracy: 0.626953
# Epoch: 71 	Training Loss: 0.923080 	Validation Loss: 1.108285
# Epoch: 71 	Training accuracy: 0.670000 	Validation accuracy: 0.611328
# Epoch: 72 	Training Loss: 0.917041 	Validation Loss: 1.110881
# Epoch: 72 	Training accuracy: 0.670875 	Validation accuracy: 0.605469
# Epoch: 73 	Training Loss: 0.912131 	Validation Loss: 1.099764
# Epoch: 73 	Training accuracy: 0.672000 	Validation accuracy: 0.608398
# Epoch: 74 	Training Loss: 0.902262 	Validation Loss: 1.116367
# Epoch: 74 	Training accuracy: 0.676750 	Validation accuracy: 0.610352
# Epoch: 75 	Training Loss: 0.907387 	Validation Loss: 1.092545
# Epoch: 75 	Training accuracy: 0.672750 	Validation accuracy: 0.607422
# Epoch: 76 	Training Loss: 0.911404 	Validation Loss: 1.096777
# Epoch: 76 	Training accuracy: 0.674750 	Validation accuracy: 0.616699
# Epoch: 77 	Training Loss: 0.900730 	Validation Loss: 1.102666
# Epoch: 77 	Training accuracy: 0.675000 	Validation accuracy: 0.612305
# Epoch: 78 	Training Loss: 0.900585 	Validation Loss: 1.098065
# Epoch: 78 	Training accuracy: 0.678250 	Validation accuracy: 0.617676
# Epoch: 79 	Training Loss: 0.904343 	Validation Loss: 1.121038
# Epoch: 79 	Training accuracy: 0.670875 	Validation accuracy: 0.617676

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar.pt'))
# Out:
# <All keys matched successfully>

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss, label = 'training loss')
plt.plot(valid_loss, label = 'validation loss')
plt.legend()

# %%
plt.plot(train_acc, label = 'training accuracy')
plt.plot(valid_acc, label = 'validation accuracy')
plt.legend()

# %% [markdown]
# ---
# ## Problem 4
#
#
# 이제 Testset에 model을 적용하여 성능을 검증하세요.
# 최종 결과는 loss와 accuracy를 출력하세요.
#
# 제공한 기본 convolution network은 testset accuracy는 70% 전후반으로 나옵니다.
# - 구조를 변경하면서 최대 성능이 나오도록 해보세요. (숙제는 아니지만, 프로젝트는 이와 매우 흡사합니다)

# %%
# track test loss
test_loss = 0.0
test_acc = 0.0

class_correct = torch.zeros(10)
class_total = torch.zeros(10)

model.eval()
# iterate over test data
for data, labels in test_loader:
    # move tensors to GPU if CUDA is available
    data, labels = data.to(device), labels.to(device)
    # forward pass: compute predicted outputs by passing inputs to the model
    logits = model(data)
    # calculate the batch loss
    loss = criterion(logits, labels)
    # update test loss 
    test_loss += loss.item()
    
    ps = F.softmax(logits, dim=1)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.reshape(top_class.shape)
    test_acc += torch.mean(equals.type(torch.float)).detach().cpu()
    
    for i in range(len(data)):
        label = labels[i]
        class_correct[label] += equals[i].item()
        class_total[label] += 1
    

# average test loss
test_loss = test_loss/len(test_loader)
test_acc = test_acc/len(test_loader)
print('Test Loss: {:.6f}\n'.format(test_loss))
print('Test Accuracy: {:.6f}\n'.format(test_acc))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            torch.sum(class_correct[i]), torch.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
# Out:
# Test Loss: 1.096749
#
# Test Accuracy: 0.614948
#
# Test Accuracy of airplane: 64% (647/1000)
# Test Accuracy of automobile: 76% (760/1000)
# Test Accuracy of  bird: 51% (512/1000)
# Test Accuracy of   cat: 42% (428/1000)
# Test Accuracy of  deer: 47% (477/1000)
# Test Accuracy of   dog: 51% (513/1000)
# Test Accuracy of  frog: 70% (700/1000)
# Test Accuracy of horse: 67% (677/1000)
# Test Accuracy of  ship: 76% (765/1000)
# Test Accuracy of truck: 66% (664/1000)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = next(dataiter)
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, int(20/2), idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
